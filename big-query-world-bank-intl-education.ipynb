# %%
import requests
import pandas as pd
import sys
from pandas.io.json import json_normalize
from datetime import datetime
import gc
from google.oauth2 import credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from google.cloud import bigquery

# %%
# Set the scopes for the desired permissions
SCOPES = ['https://www.googleapis.com/auth/bigquery']

# Create the flow for authorization
flow = InstalledAppFlow.from_client_secrets_file(
    '...', scopes=SCOPES
)
credentials = flow.run_local_server(port=0)

project_id = '...'

# Use the obtained credentials for authentication
client = bigquery.Client(credentials=credentials, project=project_id) #
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=853561264369-cg46opisk56diiv2ee4nblkb6jmtland.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A55862%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fbigquery&state=SWyqXB6KasPKC0o2IgIpTjn5Jndpze&access_type=offline

# %%
# Construct a reference to the "world_bank_intl_education" dataset
dataset_ref = client.dataset("world_bank_intl_education", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# Construct a reference to the "international_education" table
table_ref = dataset_ref.table("international_education")

# API request - fetch the table
table = client.get_table(table_ref)

# Preview the first five lines of the "international_education" table
client.list_rows(table, max_results=5).to_dataframe()
# Out:
#   country_name country_code  \
# 0         Chad          TCD
# 1         Chad          TCD
# 2         Chad          TCD
# 3         Chad          TCD
# 4         Chad          TCD
#
#                                       indicator_name indicator_code     value  \
# 0  Enrolment in lower secondary education, both s...        UIS.E.2  321921.0
# 1  Enrolment in upper secondary education, both s...        UIS.E.3   68809.0
# 2  Enrolment in upper secondary education, both s...        UIS.E.3   30551.0
# 3  Enrolment in upper secondary education, both s...        UIS.E.3   79784.0
# 4  Repeaters in primary education, all grades, bo...        UIS.R.1  282699.0
#
#    year
# 0  2012
# 1  2006
# 2  1999
# 3  2007
# 4  2006

# %% [markdown]
# ## SQL Analysis

# %% [markdown]
# ### Government expenditure on education
# Which countries spend the largest fraction of GDP on education?

# %%
data = client.list_rows(table).to_dataframe()

# %%
data
# Out:
#                                               country_name country_code  \
# 0                                                     Chad          TCD
# 1                                                     Chad          TCD
# 2                                                     Chad          TCD
# 3                                                     Chad          TCD
# 4                                                     Chad          TCD
# ...                                                    ...          ...
# 5082196  Middle East & North Africa (excluding high inc...          MNA
# 5082197  Middle East & North Africa (excluding high inc...          MNA
# 5082198  Middle East & North Africa (excluding high inc...          MNA
# 5082199  Middle East & North Africa (excluding high inc...          MNA
# 5082200  Middle East & North Africa (excluding high inc...          MNA
#
#                                             indicator_name  \
# 0        Enrolment in lower secondary education, both s...
# 1        Enrolment in lower secondary education, both s...
# 2        Enrolment in upper secondary education, both s...
# 3        Enrolment in upper secondary education, both s...
# 4        Enrolment in upper secondary education, both s...
# ...                                                    ...
# 5082196  Lower secondary completion rate, gender parity...
# 5082197  Lower secondary completion rate, gender parity...
# 5082198  Lower secondary completion rate, gender parity...
# 5082199  Lower secondary completion rate, gender parity...
# 5082200  Lower secondary completion rate, gender parity...
#
#                   indicator_code         value  year
# 0                        UIS.E.2  306639.00000  2010
# 1                        UIS.E.2  170052.00000  2004
# 2                        UIS.E.3  123744.00000  2010
# 3                        UIS.E.3   57804.00000  2004
# 4                        UIS.E.3  101428.00000  2008
# ...                          ...           ...   ...
# 5082196  UIS.AIR.2.GPV.GLAST.GPI       0.59688  1975
# 5082197  UIS.AIR.2.GPV.GLAST.GPI       0.75445  1990
# 5082198  UIS.AIR.2.GPV.GLAST.GPI       1.02373  2008
# 5082199  UIS.AIR.2.GPV.GLAST.GPI       0.94328  2000
# 5082200  UIS.AIR.2.GPV.GLAST.GPI       0.84105  1994
#
# [5082201 rows x 6 columns]

# %%
data.indicator_code.unique()
# Out:
# array(['UIS.E.2', 'UIS.E.3', 'UIS.E.4', ..., 'LO.EGRA.READ.0.KII.2GRD',
#        'LO.EGRA.CWPM.ZERO.ICI.2GRD', 'LO.EGRA.CWPM.ZERO.LUV.2GRD'],
#       dtype=object)

# %% [markdown]
# ### One interesting indicator code is SE.XPD.TOTL.GD.ZS, which corresponds to "Government expenditure on education as % of GDP (%)".

# %%
data[data['indicator_code']=='SE.XPD.TOTL.GD.ZS']
# Out:
#         country_name country_code  \
# 2212            Chad          TCD
# 2213            Chad          TCD
# 6856            Cuba          CUB
# 6857            Cuba          CUB
# 6858            Cuba          CUB
# ...              ...          ...
# 5067322       Zambia          ZMB
# 5067323       Zambia          ZMB
# 5067324       Zambia          ZMB
# 5067325       Zambia          ZMB
# 5076977     Zimbabwe          ZWE
#
#                                             indicator_name     indicator_code  \
# 2212     Government expenditure on education as % of GD...  SE.XPD.TOTL.GD.ZS
# 2213     Government expenditure on education as % of GD...  SE.XPD.TOTL.GD.ZS
# 6856     Government expenditure on education as % of GD...  SE.XPD.TOTL.GD.ZS
# 6857     Government expenditure on education as % of GD...  SE.XPD.TOTL.GD.ZS
# 6858     Government expenditure on education as % of GD...  SE.XPD.TOTL.GD.ZS
# ...                                                    ...                ...
# 5067322  Government expenditure on education as % of GD...  SE.XPD.TOTL.GD.ZS
# 5067323  Government expenditure on education as % of GD...  SE.XPD.TOTL.GD.ZS
# 5067324  Government expenditure on education as % of GD...  SE.XPD.TOTL.GD.ZS
# 5067325  Government expenditure on education as % of GD...  SE.XPD.TOTL.GD.ZS
# 5076977  Government expenditure on education as % of GD...  SE.XPD.TOTL.GD.ZS
#
#            value  year
# 2212     2.20764  2012
# 2213     2.84971  2013
# 6856     7.70486  2000
# 6857     9.94078  2003
# 6858     7.07477  1993
# ...          ...   ...
# 5067322  5.94579  1972
# 5067323  1.24076  2007
# 5067324  5.15487  1982
# 5067325  3.33899  1986
# 5076977  2.31784  1979
#
# [3538 rows x 6 columns]

# %%
query = """ 
        SELECT country_name, avg(value) as average_GDP
        FROM `bigquery-public-data.world_bank_intl_education.international_education`
        WHERE indicator_code = 'SE.XPD.TOTL.GD.ZS' and year >= 2010 and year<=2017
        GROUP BY country_name
        ORDER BY average_GDP DESC
        """

# %%
query_job = client.query(query)
country_GDP = query_job.to_dataframe()

# %%
country_GDP
# Out:
#                  country_name  average_GDP
# 0                        Cuba    12.837270
# 1       Micronesia, Fed. Sts.    12.467750
# 2             Solomon Islands    10.001080
# 3                     Moldova     8.372153
# 4                     Namibia     8.349610
# ..                        ...          ...
# 152                  Cambodia     1.706404
# 153        West Bank and Gaza     1.503760
# 154               South Sudan     1.409726
# 155                    Monaco     1.409606
# 156  Central African Republic     1.214010
#
# [157 rows x 2 columns]

# %% [markdown]
# ### Identify interesting codes to explore

# %%
query2 = """ 
        SELECT indicator_name, indicator_code, COUNT(1) as num_rows
        FROM `bigquery-public-data.world_bank_intl_education.international_education`
        GROUP BY indicator_code,indicator_name
        HAVING num_rows >= 175
        ORDER BY num_rows DESC
        """

# %%
query_job2 = client.query(query2)
country_indicator_check = query_job2.to_dataframe()

# %%
country_indicator_check
# Out:
#                                          indicator_name     indicator_code  \
# 0                                     Population, total        SP.POP.TOTL
# 1                          Population growth (annual %)        SP.POP.GROW
# 2                   Population, ages 15-64 (% of total)  SP.POP.1564.TO.ZS
# 3                    Population, ages 0-14 (% of total)  SP.POP.0014.TO.ZS
# 4                       Population, female (% of total)  SP.POP.TOTL.FE.ZS
# ...                                                 ...                ...
# 2074  TIMSS: Fourth grade students reaching the low ...  LO.TIMSS.SCI4.LOW
# 2075  TIMSS: Fourth grade students reaching the inte...  LO.TIMSS.SCI4.INT
# 2076  Percentage of teachers in post-secondary non-t...         UIS.TRTP.4
# 2077  Percentage of graduates from tertiary ISCED 6 ...          UIS.FGP.6
# 2078  Graduates from ISCED 6 programmes in tertiary ...          UIS.G.6.F
#
#       num_rows
# 0        11155
# 1        11149
# 2        10243
# 3        10233
# 4        10233
# ...        ...
# 2074       183
# 2075       183
# 2076       182
# 2077       180
# 2078       180
#
# [2079 rows x 3 columns]
