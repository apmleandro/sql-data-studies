# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('restaurant_sqlite.db')

# %%
def consulta(query):
    return pd.read_sql(query,conn)

# %%
consulta('SELECT * FROM Customers')

# %%
consulta('SELECT * FROM CustomersDishes as CD')
# Out:
#    CustomersDishesID  CustomerID  DishID
# 0                  1           7       3
# 1                  2           7       4
# 2                  3           7      21
# 3                  4          41       3
# 4                  5          41       8
# 5                  6          41       2
# 6                  7          35       8
# 7                  8          35       9

# %%
consulta('''SELECT * FROM CustomersDishes as CD JOIN OrdersDishes as OD on CD.DishID = OD.DishID''')
# Out:
#    CustomersDishesID  CustomerID  DishID  OrdersDishesID  OrderID  DishID
# 0                  1           7       3              14        7       3
# 1                  3           7      21              18       10      21
# 2                  4          41       3              14        7       3
# 3                  5          41       8              11        6       8
# 4                  7          35       8              11        6       8
# 5                  8          35       9               3        2       9
# 6                  8          35       9               8        5       9

# %%
consulta('''SELECT * 
        FROM CustomersDishes as CD 
            JOIN OrdersDishes as OD 
                on CD.DishID = OD.DishID
            JOIN Dishes as D
                on OD.DishID = D.DishID''')

# %%
consulta('''SELECT 
            C.FirstName || " " || C.LastName Name,
            D.Name Dish,
            D.Description
        FROM CustomersDishes as CD 
            JOIN OrdersDishes as OD 
                on CD.DishID = OD.DishID
            JOIN Dishes as D
                on OD.DishID = D.DishID
            JOIN Customers as C
                on CD.CustomerID = C.CustomerID
                ''')

# %%
consulta('''SELECT 
            C.FirstName || " " || C.LastName Name,
            D.Name Dish,
            D.Description
        FROM CustomersDishes as CD 
            INNER JOIN OrdersDishes as OD 
                on CD.DishID = OD.DishID
            INNER JOIN Dishes as D
                on OD.DishID = D.DishID
            INNER JOIN Customers as C
                on CD.CustomerID = C.CustomerID
                ''')

# %%
#left pega so pelo Database initial -- na esquerda
consulta('''SELECT 
            C.FirstName || " " || C.LastName Name,
            D.Name Dish,
            D.Description
        FROM CustomersDishes as CD 
            LEFT JOIN OrdersDishes as OD 
                on CD.DishID = OD.DishID
            LEFT JOIN Dishes as D
                on OD.DishID = D.DishID
            LEFT JOIN Customers as C
                on CD.CustomerID = C.CustomerID
                ''')
# Out:
#                Name                  Dish  \
# 0      Cammi Kynett     French Onion Soup
# 1      Cammi Kynett                  None
# 2      Cammi Kynett  Pomegranate Iced Tea
# 3  Lowrance Gratton     French Onion Soup
# 4  Lowrance Gratton          Chef's Salad
# 5  Lowrance Gratton                  None
# 6    Luciano Winton          Chef's Salad
# 7    Luciano Winton   Quinoa Salmon Salad
# 8    Luciano Winton   Quinoa Salmon Salad
#
#                                          Description
# 0  Caramelized onions slow cooked in a savory bro...
# 1                                               None
# 2  Our unique blend of pomegranate juice, black R...
# 3  Caramelized onions slow cooked in a savory bro...
# 4  The chef's salad has cucumber, tomatoes, red o...
# 5                                               None
# 6  The chef's salad has cucumber, tomatoes, red o...
# 7  Our quinoa salad is served with quinoa, tomato...
# 8  Our quinoa salad is served with quinoa, tomato...

# %%
#left pega so pelo Database initial -- na esquerda
consulta('''SELECT 
            C.FirstName || " " || C.LastName Name,
            D.Name Dish,
            D.Description,
            D.Price
        FROM CustomersDishes as CD 
            LEFT JOIN OrdersDishes as OD 
                on CD.DishID = OD.DishID
            LEFT JOIN Dishes as D
                on OD.DishID = D.DishID
            LEFT JOIN Customers as C
                on CD.CustomerID = C.CustomerID
                ''')

# %%
#Soma
consulta('''SELECT 
            SUM(D.Price)
        FROM CustomersDishes as CD 
            JOIN OrdersDishes as OD 
                on CD.DishID = OD.DishID
            JOIN Dishes as D
                on OD.DishID = D.DishID
            JOIN Customers as C
                on CD.CustomerID = C.CustomerID
                ''')
# Out:
#    SUM(D.Price)
# 0         55.98

# %%
#Soma
consulta('''SELECT 
            MAX(D.Price)
        FROM CustomersDishes as CD 
            JOIN OrdersDishes as OD 
                on CD.DishID = OD.DishID
            JOIN Dishes as D
                on OD.DishID = D.DishID
            JOIN Customers as C
                on CD.CustomerID = C.CustomerID
                ''')
# Out:
#    MAX(D.Price)
# 0          9.99

# %%
#Soma
consulta('''SELECT 
            MIN(D.Price)
        FROM CustomersDishes as CD 
            JOIN OrdersDishes as OD 
                on CD.DishID = OD.DishID
            JOIN Dishes as D
                on OD.DishID = D.DishID
            JOIN Customers as C
                on CD.CustomerID = C.CustomerID
                ''')
# Out:
#    MIN(D.Price)
# 0           4.0

# %%
#Soma
consulta('''SELECT 
            AVG(D.Price)
        FROM CustomersDishes as CD 
            JOIN OrdersDishes as OD 
                on CD.DishID = OD.DishID
            JOIN Dishes as D
                on OD.DishID = D.DishID
            JOIN Customers as C
                on CD.CustomerID = C.CustomerID
                ''')
# Out:
#    AVG(D.Price)
# 0      7.997143

# %%
# Calculo por grupo
consulta('''SELECT 
            SUM(D.Price)
            CD.
        FROM CustomersDishes as CD 
            JOIN OrdersDishes as OD 
                on CD.DishID = OD.DishID
            JOIN Dishes as D
                on OD.DishID = D.DishID
            JOIN Customers as C
                on CD.CustomerID = C.CustomerID
            GROUP BY CD.CustomerID
                ''')
# Out:
#    SUM(D.Price)
# 0         11.00
# 1         28.98
# 2         16.00

# %%
# Calculo por grupo
consulta('''SELECT 
            C.FirstName || " " || C.LastName Name,
            SUM(D.Price),
            D.Name
        FROM CustomersDishes as CD 
            JOIN OrdersDishes as OD 
                on CD.DishID = OD.DishID
            JOIN Dishes as D
                on OD.DishID = D.DishID
            JOIN Customers as C
                on CD.CustomerID = C.CustomerID
            GROUP BY D.Name
                ''')
# Out:
#                Name  SUM(D.Price)                  Name
# 0  Lowrance Gratton         18.00          Chef's Salad
# 1      Cammi Kynett         14.00     French Onion Soup
# 2      Cammi Kynett          4.00  Pomegranate Iced Tea
# 3    Luciano Winton         19.98   Quinoa Salmon Salad

# %%
# Calculo por grupo
consulta('''SELECT 
            C.FirstName || " " || C.LastName Name,
            D.Name,
            D.Price
        FROM CustomersDishes as CD 
            JOIN OrdersDishes as OD 
                on CD.DishID = OD.DishID
            JOIN Dishes as D
                on OD.DishID = D.DishID
            JOIN Customers as C
                on CD.CustomerID = C.CustomerID
                ''')
# Out:
#                Name                  Name  Price
# 0      Cammi Kynett     French Onion Soup   7.00
# 1      Cammi Kynett  Pomegranate Iced Tea   4.00
# 2  Lowrance Gratton     French Onion Soup   7.00
# 3  Lowrance Gratton          Chef's Salad   9.00
# 4    Luciano Winton          Chef's Salad   9.00
# 5    Luciano Winton   Quinoa Salmon Salad   9.99
# 6    Luciano Winton   Quinoa Salmon Salad   9.99

# %%
dados = {}
cursor = conn.cursor()
names =[]
var_names = []
var_type = []
check_null =[]
#Master listing of all database objects in the database and the SQL used to create each object.
cursor.execute('SELECT name FROM sqlite_master WHERE TYPE = "table"')
name = cursor.fetchall()
for n in name: # [("Directors",), ("Actors",) ..]
    nome = n[0]
    cursor.execute(f"PRAGMA table_info({n[0]})") #[(0,id,integral,0,0,1), (...), (...)]
    for row in cursor.fetchall():
        names.append(n[0])
        var_names.append(row[1])
        var_type.append(row[2])
        #SELECT COUNT(*) FROM your_table WHERE your_column IS NULL;
        cursor.execute(f'SELECT COUNT(*) FROM {n[0]} WHERE {row[1]} IS NULL;')
        check = cursor.fetchall() # returns list of tuples ex.[(0,)]
        if check[0][0] >0:
            check_null.append("Yes")
        else:
            check_null.append("No")

dados = {"Table" : names, "Variable Names": var_names , "Variables Types" : var_type, "Null Values": check_null}       

df = pd.DataFrame(dados)
 
print(df)
# Out:
#               Table     Variable Names Variables Types Null Values
# 0      Reservations      ReservationID         INTEGER          No
# 1      Reservations         CustomerID         INTEGER          No
# 2      Reservations               Date            TEXT          No
# 3      Reservations          PartySize         INTEGER          No
# 4      OrdersDishes     OrdersDishesID         INTEGER          No
# 5      OrdersDishes            OrderID         INTEGER          No
# 6      OrdersDishes             DishID         INTEGER          No
# 7            Orders            OrderID         INTEGER          No
# 8            Orders         CustomerID         INTEGER          No
# 9            Orders          OrderDate            TEXT          No
# 10  EventsLocations                 id         INTEGER          No
# 11  EventsLocations          EventName            TEXT          No
# 12  EventsLocations           Location            TEXT          No
# ...
